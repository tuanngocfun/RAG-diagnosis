# %%
# !export HF_HUB_OFFLINE=0
# !export TRANSFORMERS_OFFLINE=0

# %%
from transformers import AutoTokenizer, AutoModel
import os

# Force Hugging Face to store models under your project path
os.environ["HF_HOME"]       = "/data4t/hf"
os.environ["HF_HUB_CACHE"]  = "/data4t/hf/hub"
os.environ["TRANSFORMERS_CACHE"] = "/data4t/hf/transformers"

model_id = "intfloat/multilingual-e5-large-instruct"

print(f"⬇️  Downloading and caching {model_id} ...")

# Download both tokenizer & model
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModel.from_pretrained(model_id)

print(f"✅ Model cached at: {os.environ['TRANSFORMERS_CACHE']}/models--intfloat--multilingual-e5-large-instruct")
# Out:
# /home/students/Leishmania/.venv/lib/python3.11/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# ⬇️  Downloading and caching intfloat/multilingual-e5-large-instruct ...
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# Could not set the permissions on the file '/data4t/hf/transformers/models--intfloat--multilingual-e5-large-instruct/blobs/bc9cb006ea6982868d4e32f58506b1d17873b21f.incomplete'. Error: [Errno 1] Operation not permitted: '/data4t/hf/transformers/models--intfloat--multilingual-e5-large-instruct/blobs/bc9cb006ea6982868d4e32f58506b1d17873b21f.incomplete'.
# Continuing without setting permissions.
# ...

# %%
# !uv pip install huggingface_hub
# Out:
# Audited 1 package in 12ms

# %%
from dotenv import load_dotenv
from huggingface_hub import login
from pathlib import Path
import os
# Find and load the variables from your .env file
load_dotenv()

# Load all your API keys into variables
HF_TOKEN = os.getenv("HF_TOKEN")
if HF_TOKEN:
    try:
        login(token=HF_TOKEN)
        print("✅ Successfully logged in to Hugging Face.")
    except Exception as e:
        print(f"❌ Failed to log in to Hugging Face: {e}")
else:
    print("⚠️ Hugging Face token (HF_TOKEN) not found in .env file.")
# Out:
# Note: Environment variable`HF_TOKEN` is set and is the current active token independently from the token you've just configured.
# ✅ Successfully logged in to Hugging Face.

# %%
import os
import torch

os.environ["HF_HOME"]       = "/data4t/hf"
os.environ["HF_HUB_CACHE"]  = "/data4t/hf/hub"
os.environ["TRANSFORMERS_CACHE"] = "/data4t/hf/transformers"

from transformers import pipeline
# now everything will go under /media/…/ngoc/hf/…
pipe = pipeline(
    "text-generation",
    model="mistralai/Mistral-7B-Instruct-v0.1",
    torch_dtype=torch.float16,
    device_map="auto",
    # you can still pass cache_dir here, but HF_HOME is the real driver now
    cache_dir="/media/pc1/Ubuntu/Extend_Data/ngoc/hf"
)
# Out:
# /home/students/Leishmania/.venv/lib/python3.11/site-packages/transformers/utils/hub.py:111: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Could not set the permissions on the file '/data4t/hf/transformers/models--mistralai--Mistral-7B-Instruct-v0.1/blobs/f4989f072a7f517d01d479eb1685c6e50e014f88.incomplete'. Error: [Errno 1] Operation not permitted: '/data4t/hf/transformers/models--mistralai--Mistral-7B-Instruct-v0.1/blobs/f4989f072a7f517d01d479eb1685c6e50e014f88.incomplete'.
# Continuing without setting permissions.
# ...
